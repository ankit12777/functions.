# %% [markdown]
# ## THEORY QUESTION
# 1. What is the difference between a function and a method in Python?
#      Function: A standalone block of code, defined using def, not tied to any object.
# Example: len("abc")
# Method: A function that is associated with an object (belongs to a class) and is called on that object.
# Example: "abc".upper()
#
# 2. Explain the concept of function arguments and parameters in Python.
#       Parameters: Variables listed in the function definition.
# Example:
#
# def add(a, b):  # a, b are parameters
#     return a + b
#
# Arguments: Actual values passed to the function when calling it.
# Example:
#
# add(2, 3)  # 2, 3 are arguments
#
# 3. What are the different ways to define and call a function in Python?
#     1. Simple function
# def greet():
#     print("Hello")
# greet()
# 2. Function with parameters
# def add(a, b):
#     return a + b
# add(2, 3)
# 3. Default arguments
# def greet(name="User"):
#     print(name)
# greet()
# greet("Aman")
#
# 4. What is the purpose of the `return` statement in a Python function?
#       Purpose of return in Python:
#
# The return statement is used to send a result back from a function to the caller.
# It ends the function execution immediately.
#
# 5. What are iterators in Python and how do they differ from iterables?
#      Iterable: An object that can be looped over (e.g., list, tuple, string). It implements __iter__() and returns an iterator.
# Example: [1, 2, 3]
# Iterator: An object that keeps track of iteration state and produces values one at a time using __next__().
#
# 6. Explain the concept of generators in Python and how they are defined.
#       Generators in Python (crisp):
#
# Generator: A special type of iterator that yields values one at a time instead of returning all at once, saving memory.
# Defined using a function with the yield keyword (instead of return.
#
# 7. What are the advantages of using generators over regular functions?
#      Memory efficient: Generate values one at a time instead of storing all at once
# Lazy evaluation: Compute values only when needed
# Faster for large data: Avoids creating big data structures.
#
# 8. What is a lambda function in Python and when is it typically used?
#        A lambda function is a small anonymous (unnamed) function defined using the lambda keyword.
# It can have any number of inputs but only one expression.
#
# 9. Explain the purpose and usage of the `map()` function in Python.
#      map() in Python (crisp):
#
# map() applies a function to each item in an iterable and returns a map object (iterator).
#
# Syntax:
#
# map(function, iterable)
#
# 10. What is the difference between `map()`, `reduce()`, and `filter()` functions in Python?
#     Difference between map(), filter(), and reduce() (crisp):
#
# map(): Applies a function to each element → returns transformed iterable
#
# map(lambda x: x*2, [1,2,3])  # [2,4,6]

# %% [markdown]
# ##PRATICAL QUESTION -ANSWERS

# %% [markdown]
# 1. Write a Python function that takes a list of numbers as input and returns the sum of all even numbers in
# the list.

# %%
def sum_even_numbers(nums):
    total = 0
    for num in nums:
        if num % 2 == 0:
            total += num
    return total

# Example usage
print(sum_even_numbers([1, 2, 3, 4, 5, 6]))  # Output: 12

# %% [markdown]
# 2. Create a Python function that accepts a string and returns the reverse of that string.

# %%
def reverse_string(s):
    return s[::-1]

# Example usage
print(reverse_string("hello"))  # Output: "olleh"

# %% [markdown]
# 3. Implement a Python function that takes a list of integers and returns a new list containing the squares of
# each number.

# %%
def square_numbers(nums):
    result = []
    for num in nums:
        result.append(num ** 2)
    return result

# Example usage
print(square_numbers([1, 2, 3, 4]))  # Output: [1, 4, 9, 16]

# %% [markdown]
# 4. Write a Python function that checks if a given number is prime or not from 1 to 200.

# %%
def is_prime(n):
    if n < 2:
        return False
    for i in range(2, int(n ** 0.5) + 1):
        if n % i == 0:
            return False
    return True

# Check primes from 1 to 200
def primes_1_to_200():
    primes = []
    for num in range(1, 201):
        if is_prime(num):
            primes.append(num)
    return primes

# Example usage
print(primes_1_to_200())

# %% [markdown]
# 5. Create an iterator class in Python that generates the Fibonacci sequence up to a specified number of
# terms.

# %%
class FibonacciIterator:
    def __init__(self, n_terms):
        self.n_terms = n_terms
        self.count = 0
        self.a, self.b = 0, 1  # first two Fibonacci numbers

    def __iter__(self):
        return self

    def __next__(self):
        if self.count >= self.n_terms:
            raise StopIteration

        # return current Fibonacci number
        value = self.a

        # update values for next term
        self.a, self.b = self.b, self.a + self.b
        self.count += 1

        return value


# Example usage
fib = FibonacciIterator(10)

for num in fib:
    print(num)

# %% [markdown]
# 6. Write a generator function in Python that yields the powers of 2 up to a given exponent.

# %%
def powers_of_two(exponent):
    for i in range(exponent + 1):
        yield 2 ** i

# Example usage
for value in powers_of_two(5):
    print(value)

Output:

1
2
4
8
16
32

# %% [markdown]
# 7. Implement a generator function that reads a file line by line and yields each line as a string.

# %%
def read_file_line_by_line(file_path):
    with open(file_path, "r") as file:
        for line in file:
            yield line.strip()

# Example usage
# for line in read_file_line_by_line("example.txt"):

# %% [markdown]
# 8. Use a lambda function in Python to sort a list of tuples based on the second element of each tuple.

# %%
# List of tuples
data = [(1, 3), (4, 1), (2, 5), (3, 2)]

# Sorting using lambda (based on 2nd element)
sorted_data = sorted(data, key=lambda x: x[1])

print(sorted_data)
